# %% [markdown]
# # Predict whether a mammogram mass is benign or malignant

# %% [markdown]
# <img src="images/Mamo.png" height="500" width="500">
#
# Picture Courtesy: https://www.sentara.com

# %% [markdown]
# We'll be using the "mammographic masses" public dataset from the UCI repository (source: https://archive.ics.uci.edu/ml/datasets/Mammographic+Mass)
#
# This data contains 961 instances of masses detected in mammograms, and contains the following attributes:
#
#
#    1. BI-RADS assessment: 1 to 5 (ordinal)
#    2. Age: patient's age in years (integer)
#    3. Shape: mass shape: round=1 oval=2 lobular=3 irregular=4 (nominal)
#    4. Margin: mass margin: circumscribed=1 microlobulated=2 obscured=3 ill-defined=4 spiculated=5 (nominal)
#    5. Density: mass density high=1 iso=2 low=3 fat-containing=4 (ordinal)
#    6. Severity: benign=0 or malignant=1 (binominal)
#
# BI-RADS is an assesment of how confident the severity classification is; it is not a "predictive" attribute and so we will discard it. The age, shape, margin, and density attributes are the features that we will build our model with, and "severity" is the classification we will attempt to predict based on those attributes.
#
# Although "shape" and "margin" are nominal data types, which sklearn typically doesn't deal with well, they are close enough to ordinal that we shouldn't just discard them. The "shape" for example is ordered increasingly from round to irregular.
#
# A lot of unnecessary anguish and surgery arises from false positives arising from mammogram results. If we can build a better way to interpret them through supervised machine learning, it could improve a lot of lives.

# %% [markdown]
# ## Road Map:
#
# Build a Multi-Layer Perceptron and train it to classify masses as benign or malignant based on its features.
#
# The data needs to be cleaned; many rows contain missing data, and there may be erroneous data identifiable as outliers as well.
#
# Remember to normalize your data first! And experiment with different topologies, optimizers, and hyperparameters.
#
# I was able to achieve over 80% accuracy - can you beat that?

# %% [markdown]
# ## Let's begin: prepare your data
#
# Start by importing the mammographic_masses.data.txt file into a Pandas dataframe (hint: use read_csv) and take a look at it.

# %%
import pandas as pd

masses_data = pd.read_csv('mammographic_masses.data.txt')
masses_data.head()
# Out:
#    5  67  3 5.1 3.1  1
# 0  4  43  1   1   ?  1
# 1  5  58  4   5   3  1
# 2  4  28  1   1   3  0
# 3  5  74  1   5   ?  1
# 4  4  65  1   ?   3  0

# %% [markdown]
# Make sure you use the optional parmaters in read_csv to convert missing data (indicated by a ?) into NaN, and to add the appropriate column names (BI_RADS, age, shape, margin, density, and severity):

# %%
masses_data = pd.read_csv('mammographic_masses.data.txt', na_values=['?'], names = ['BI-RADS', 'age', 'shape', 'margin', 'density', 'severity'])
masses_data.head()
# Out:
#    BI-RADS   age  shape  margin  density  severity
# 0      5.0  67.0    3.0     5.0      3.0         1
# 1      4.0  43.0    1.0     1.0      NaN         1
# 2      5.0  58.0    4.0     5.0      3.0         1
# 3      4.0  28.0    1.0     1.0      3.0         0
# 4      5.0  74.0    1.0     5.0      NaN         1

# %% [markdown]
# Evaluate whether the data needs cleaning; your model is only as good as the data it's given. Hint: use describe() on the dataframe.

# %%
masses_data.describe()
# Out:
#           BI-RADS         age       shape      margin     density    severity
# count  959.000000  956.000000  930.000000  913.000000  885.000000  961.000000
# mean     4.348279   55.487448    2.721505    2.796276    2.910734    0.463059
# std      1.783031   14.480131    1.242792    1.566546    0.380444    0.498893
# min      0.000000   18.000000    1.000000    1.000000    1.000000    0.000000
# 25%      4.000000   45.000000    2.000000    1.000000    3.000000    0.000000
# 50%      4.000000   57.000000    3.000000    3.000000    3.000000    0.000000
# 75%      5.000000   66.000000    4.000000    4.000000    3.000000    1.000000
# max     55.000000   96.000000    4.000000    5.000000    4.000000    1.000000

# %% [markdown]
# There are quite a few missing values in the data set. Before we just drop every row that's missing data, let's make sure we don't bias our data in doing so. Does there appear to be any sort of correlation to what sort of data has missing fields? If there were, we'd have to try and go back and fill that data in.

# %%
masses_data.loc[(masses_data['age'].isnull()) |
              (masses_data['shape'].isnull()) |
              (masses_data['margin'].isnull()) |
              (masses_data['density'].isnull())]
# Out:
#      BI-RADS   age  shape  margin  density  severity
# 1        4.0  43.0    1.0     1.0      NaN         1
# 4        5.0  74.0    1.0     5.0      NaN         1
# 5        4.0  65.0    1.0     NaN      3.0         0
# 6        4.0  70.0    NaN     NaN      3.0         0
# 7        5.0  42.0    1.0     NaN      3.0         0
# 9        5.0  60.0    NaN     5.0      1.0         1
# 12       4.0  64.0    1.0     NaN      3.0         0
# 19       4.0  40.0    1.0     NaN      NaN         0
# 20       NaN  66.0    NaN     NaN      1.0         1
# 22       4.0  43.0    1.0     NaN      NaN         0
# 26       2.0  66.0    1.0     1.0      NaN         0
# 27       5.0  63.0    3.0     NaN      3.0         0
# 35       4.0  77.0    3.0     NaN      NaN         0
# 38       4.0  48.0    4.0     5.0      NaN         1
# 40       4.0  59.0    2.0     1.0      NaN         0
# 43       4.0  61.0    2.0     1.0      NaN         0
# 45       5.0  44.0    2.0     4.0      NaN         1
# 47       4.0  23.0    1.0     1.0      NaN         0
# 48       2.0  42.0    NaN     NaN      4.0         0
# 52       4.0  23.0    1.0     1.0      NaN         0
# 53       4.0  63.0    2.0     1.0      NaN         0
# 54       4.0  53.0    NaN     5.0      3.0         1
# 55       4.0  43.0    3.0     4.0      NaN         0
# 57       5.0  51.0    2.0     4.0      NaN         0
# 58       4.0  45.0    2.0     1.0      NaN         0
# 59       5.0  59.0    2.0     NaN      NaN         1
# 63       3.0  57.0    2.0     1.0      NaN         0
# 65       4.0  25.0    2.0     1.0      NaN         0
# 67       5.0  72.0    4.0     3.0      NaN         1
# 74       5.0  70.0    NaN     4.0      NaN         1
# ..       ...   ...    ...     ...      ...       ...
# 496      4.0  82.0    NaN     5.0      3.0         1
# 501      5.0  59.0    4.0     4.0      NaN         1
# 519      3.0  68.0    NaN     NaN      3.0         0
# 520      4.0  62.0    4.0     NaN      3.0         1
# 521      5.0  65.0    1.0     NaN      3.0         1
# 531      4.0  55.0    NaN     NaN      3.0         0
# 537      5.0  63.0    NaN     4.0      3.0         1
# 541      4.0  49.0    2.0     NaN      3.0         0
# 554      5.0  70.0    NaN     5.0      3.0         1
# 561      2.0  59.0    NaN     4.0      3.0         0
# 569      4.0  64.0    3.0     4.0      NaN         1
# 574      4.0  60.0    3.0     NaN      NaN         0
# 581      2.0  65.0    NaN     1.0      2.0         0
# 614      3.0  46.0    NaN     5.0      NaN         1
# 627      4.0  57.0    2.0     1.0      NaN         0
# 660      4.0  58.0    NaN     4.0      3.0         1
# 661      4.0  51.0    NaN     4.0      3.0         0
# 662      3.0  50.0    NaN     NaN      3.0         1
# 665      4.0  27.0    2.0     1.0      NaN         0
# 677      4.0  57.0    4.0     4.0      NaN         1
# 683      5.0   NaN    3.0     3.0      3.0         1
# 691      4.0  72.0    3.0     NaN      3.0         0
# 723      4.0  60.0    3.0     NaN      4.0         0
# 745      6.0  76.0    3.0     NaN      3.0         0
# 752      5.0  48.0    NaN     4.0      NaN         1
# 778      4.0  60.0    NaN     4.0      3.0         0
# 819      4.0  35.0    3.0     NaN      2.0         0
# 824      6.0  40.0    NaN     3.0      4.0         1
# 884      5.0   NaN    4.0     4.0      3.0         1
# 923      5.0   NaN    4.0     3.0      3.0         1
#
# [130 rows x 6 columns]

# %% [markdown]
# If the missing data seems randomly distributed, go ahead and drop rows with missing data. Hint: use dropna().

# %%
masses_data.dropna(inplace=True)
masses_data.describe()
# Out:
#           BI-RADS         age       shape      margin     density    severity
# count  830.000000  830.000000  830.000000  830.000000  830.000000  830.000000
# mean     4.393976   55.781928    2.781928    2.813253    2.915663    0.485542
# std      1.888371   14.671782    1.242361    1.567175    0.350936    0.500092
# min      0.000000   18.000000    1.000000    1.000000    1.000000    0.000000
# 25%      4.000000   46.000000    2.000000    1.000000    3.000000    0.000000
# 50%      4.000000   57.000000    3.000000    3.000000    3.000000    0.000000
# 75%      5.000000   66.000000    4.000000    4.000000    3.000000    1.000000
# max     55.000000   96.000000    4.000000    5.000000    4.000000    1.000000

# %% [markdown]
# Next you'll need to convert the Pandas dataframes into numpy arrays that can be used by scikit_learn. Create an array that extracts only the feature data we want to work with (age, shape, margin, and density) and another array that contains the classes (severity). You'll also need an array of the feature name labels.

# %%
all_features = masses_data[['age', 'shape',
                             'margin', 'density']].values


all_classes = masses_data['severity'].values

feature_names = ['age', 'shape', 'margin', 'density']

#all_features
#all_classes

# %% [markdown]
# Some of our models require the input data to be normalized, so go ahead and normalize the attribute data. Hint: use preprocessing.StandardScaler().

# %%
from sklearn import preprocessing

scaler = preprocessing.StandardScaler()
all_features_scaled = scaler.fit_transform(all_features)
all_features_scaled
# Out:
# array([[ 0.7650629 ,  0.17563638,  1.39618483,  0.24046607],
#        [ 0.15127063,  0.98104077,  1.39618483,  0.24046607],
#        [-1.89470363, -1.43517241, -1.157718  ,  0.24046607],
#        ...,
#        [ 0.56046548,  0.98104077,  1.39618483,  0.24046607],
#        [ 0.69686376,  0.98104077,  1.39618483,  0.24046607],
#        [ 0.42406719,  0.17563638,  0.11923341,  0.24046607]])

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(masses_data, all_classes, test_size=0.4, random_state=0)

# %% [markdown]
# ## 4. Building the  model architecture
# Build a model here using sequential. Feel free to experiment with different layers and sizes! Also, experiment adding dropout to reduce overfitting.

# %%
# Imports
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation


np.random.seed(42)

# %%
# Building the model architecture with one layer of length 4


model = Sequential()
model.add(Dense(4, activation='relu', input_dim= 6))
model.add(Dropout(0.2))
model.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))
   
    
    
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 4)                 28
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4)                 0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 33
# Trainable params: 33
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model using categorical_crossentropy loss, and rmsprop optimizer.
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
# Running and evaluating the model
hist = model.fit(x_train, y_train,
          batch_size=16,
          epochs=100,
          validation_data=(x_test, y_test), 
          verbose=2)
# Out:
# Train on 498 samples, validate on 332 samples
# Epoch 1/100
#  - 0s - loss: 0.2670 - acc: 0.9036 - val_loss: 0.0895 - val_acc: 0.9970
# Epoch 2/100
#  - 0s - loss: 0.2893 - acc: 0.8916 - val_loss: 0.0893 - val_acc: 1.0000
# Epoch 3/100
#  - 0s - loss: 0.2373 - acc: 0.9197 - val_loss: 0.0887 - val_acc: 1.0000
# Epoch 4/100
#  - 0s - loss: 0.2558 - acc: 0.9096 - val_loss: 0.0888 - val_acc: 0.9970
# Epoch 5/100
#  - 0s - loss: 0.2334 - acc: 0.9217 - val_loss: 0.0873 - val_acc: 1.0000
# Epoch 6/100
#  - 0s - loss: 0.2446 - acc: 0.9157 - val_loss: 0.0875 - val_acc: 1.0000
# Epoch 7/100
#  - 0s - loss: 0.2857 - acc: 0.8936 - val_loss: 0.0886 - val_acc: 0.9970
# Epoch 8/100
#  - 0s - loss: 0.3006 - acc: 0.8855 - val_loss: 0.0891 - val_acc: 0.9970
# Epoch 9/100
#  - 0s - loss: 0.2446 - acc: 0.9157 - val_loss: 0.0888 - val_acc: 0.9970
# Epoch 10/100
#  - 0s - loss: 0.2409 - acc: 0.9177 - val_loss: 0.0886 - val_acc: 0.9970
# Epoch 11/100
#  - 0s - loss: 0.2708 - acc: 0.9016 - val_loss: 0.0872 - val_acc: 1.0000
# Epoch 12/100
#  - 0s - loss: 0.2333 - acc: 0.9217 - val_loss: 0.0867 - val_acc: 1.0000
# Epoch 13/100
#  - 0s - loss: 0.2932 - acc: 0.8896 - val_loss: 0.0874 - val_acc: 1.0000
# Epoch 14/100
#  - 0s - loss: 0.2857 - acc: 0.8936 - val_loss: 0.0889 - val_acc: 0.9970
# Epoch 15/100
#  - 0s - loss: 0.2745 - acc: 0.8996 - val_loss: 0.0873 - val_acc: 1.0000
# Epoch 16/100
#  - 0s - loss: 0.2856 - acc: 0.8936 - val_loss: 0.0875 - val_acc: 1.0000
# Epoch 17/100
#  - 0s - loss: 0.2408 - acc: 0.9177 - val_loss: 0.0874 - val_acc: 1.0000
# Epoch 18/100
#  - 0s - loss: 0.2557 - acc: 0.9096 - val_loss: 0.0886 - val_acc: 0.9970
# Epoch 19/100
#  - 0s - loss: 0.2523 - acc: 0.9116 - val_loss: 0.0880 - val_acc: 0.9970
# Epoch 20/100
#  - 0s - loss: 0.2482 - acc: 0.9137 - val_loss: 0.0877 - val_acc: 0.9970
# Epoch 21/100
#  - 0s - loss: 0.3194 - acc: 0.8755 - val_loss: 0.0883 - val_acc: 0.9970
# Epoch 22/100
#  - 0s - loss: 0.2782 - acc: 0.8976 - val_loss: 0.0885 - val_acc: 0.9970
# Epoch 23/100
#  - 0s - loss: 0.2520 - acc: 0.9116 - val_loss: 0.0869 - val_acc: 1.0000
# Epoch 24/100
#  - 0s - loss: 0.2632 - acc: 0.9056 - val_loss: 0.0866 - val_acc: 1.0000
# Epoch 25/100
#  - 0s - loss: 0.2707 - acc: 0.9016 - val_loss: 0.0867 - val_acc: 1.0000
# Epoch 26/100
#  - 0s - loss: 0.2632 - acc: 0.9056 - val_loss: 0.0867 - val_acc: 1.0000
# Epoch 27/100
#  - 0s - loss: 0.3044 - acc: 0.8835 - val_loss: 0.0880 - val_acc: 0.9970
# Epoch 28/100
#  - 0s - loss: 0.2595 - acc: 0.9076 - val_loss: 0.0867 - val_acc: 1.0000
# Epoch 29/100
#  - 0s - loss: 0.2670 - acc: 0.9036 - val_loss: 0.0868 - val_acc: 1.0000
# Epoch 30/100
#  - 0s - loss: 0.3006 - acc: 0.8855 - val_loss: 0.0871 - val_acc: 1.0000
# Epoch 31/100
#  - 0s - loss: 0.2333 - acc: 0.9217 - val_loss: 0.0867 - val_acc: 1.0000
# Epoch 32/100
#  - 0s - loss: 0.2932 - acc: 0.8896 - val_loss: 0.0882 - val_acc: 0.9970
# Epoch 33/100
#  - 0s - loss: 0.3044 - acc: 0.8835 - val_loss: 0.0875 - val_acc: 1.0000
# Epoch 34/100
#  - 0s - loss: 0.3154 - acc: 0.8775 - val_loss: 0.0881 - val_acc: 1.0000
# Epoch 35/100
#  - 0s - loss: 0.2781 - acc: 0.8976 - val_loss: 0.0883 - val_acc: 1.0000
# Epoch 36/100
#  - 0s - loss: 0.2558 - acc: 0.9096 - val_loss: 0.0881 - val_acc: 1.0000
# Epoch 37/100
#  - 0s - loss: 0.2595 - acc: 0.9076 - val_loss: 0.0881 - val_acc: 0.9970
# Epoch 38/100
#  - 0s - loss: 0.2782 - acc: 0.8976 - val_loss: 0.0875 - val_acc: 1.0000
# Epoch 39/100
#  - 0s - loss: 0.2856 - acc: 0.8936 - val_loss: 0.0879 - val_acc: 1.0000
# Epoch 40/100
#  - 0s - loss: 0.2670 - acc: 0.9036 - val_loss: 0.0879 - val_acc: 1.0000
# Epoch 41/100
#  - 0s - loss: 0.2819 - acc: 0.8956 - val_loss: 0.0881 - val_acc: 1.0000
# Epoch 42/100
#  - 0s - loss: 0.2707 - acc: 0.9016 - val_loss: 0.0879 - val_acc: 1.0000
# Epoch 43/100
#  - 0s - loss: 0.2483 - acc: 0.9137 - val_loss: 0.0879 - val_acc: 1.0000
# Epoch 44/100
#  - 0s - loss: 0.2744 - acc: 0.8996 - val_loss: 0.0889 - val_acc: 0.9970
# Epoch 45/100
#  - 0s - loss: 0.2633 - acc: 0.9056 - val_loss: 0.0878 - val_acc: 1.0000
# Epoch 46/100
#  - 0s - loss: 0.2670 - acc: 0.9036 - val_loss: 0.0878 - val_acc: 1.0000
# Epoch 47/100
#  - 0s - loss: 0.2856 - acc: 0.8936 - val_loss: 0.0880 - val_acc: 1.0000
# Epoch 48/100
#  - 0s - loss: 0.2483 - acc: 0.9137 - val_loss: 0.0876 - val_acc: 0.9970
# Epoch 49/100
#  - 0s - loss: 0.2558 - acc: 0.9096 - val_loss: 0.0876 - val_acc: 0.9970
# Epoch 50/100
#  - 0s - loss: 0.2632 - acc: 0.9056 - val_loss: 0.0880 - val_acc: 0.9970
# Epoch 51/100
#  - 0s - loss: 0.2296 - acc: 0.9237 - val_loss: 0.0885 - val_acc: 0.9970
# Epoch 52/100
#  - 0s - loss: 0.2782 - acc: 0.8976 - val_loss: 0.0867 - val_acc: 1.0000
# Epoch 53/100
#  - 0s - loss: 0.2670 - acc: 0.9036 - val_loss: 0.0866 - val_acc: 1.0000
# Epoch 54/100
#  - 0s - loss: 0.2745 - acc: 0.8996 - val_loss: 0.0867 - val_acc: 1.0000
# Epoch 55/100
#  - 0s - loss: 0.2332 - acc: 0.9217 - val_loss: 0.0860 - val_acc: 1.0000
# Epoch 56/100
#  - 0s - loss: 0.2595 - acc: 0.9076 - val_loss: 0.0860 - val_acc: 1.0000
# Epoch 57/100
#  - 0s - loss: 0.2595 - acc: 0.9076 - val_loss: 0.0861 - val_acc: 1.0000
# Epoch 58/100
#  - 0s - loss: 0.2217 - acc: 0.9277 - val_loss: 0.0865 - val_acc: 0.9970
# Epoch 59/100
#  - 0s - loss: 0.2595 - acc: 0.9076 - val_loss: 0.0851 - val_acc: 1.0000
# Epoch 60/100
#  - 0s - loss: 0.2708 - acc: 0.9016 - val_loss: 0.0851 - val_acc: 1.0000
# Epoch 61/100
#  - 0s - loss: 0.2670 - acc: 0.9036 - val_loss: 0.0850 - val_acc: 1.0000
# Epoch 62/100
#  - 0s - loss: 0.2595 - acc: 0.9076 - val_loss: 0.0850 - val_acc: 1.0000
# Epoch 63/100
#  - 0s - loss: 0.2329 - acc: 0.9217 - val_loss: 0.0844 - val_acc: 1.0000
# Epoch 64/100
#  - 0s - loss: 0.2747 - acc: 0.8996 - val_loss: 0.0848 - val_acc: 1.0000
# Epoch 65/100
#  - 0s - loss: 0.2860 - acc: 0.8936 - val_loss: 0.0854 - val_acc: 0.9970
# Epoch 66/100
#  - 0s - loss: 0.1949 - acc: 0.9418 - val_loss: 0.0873 - val_acc: 0.9970
# Epoch 67/100
#  - 0s - loss: 0.2672 - acc: 0.9036 - val_loss: 0.0845 - val_acc: 0.9970
# Epoch 68/100
#  - 0s - loss: 0.2747 - acc: 0.8996 - val_loss: 0.0845 - val_acc: 0.9970
# Epoch 69/100
#  - 0s - loss: 0.2480 - acc: 0.9137 - val_loss: 0.0843 - val_acc: 0.9970
# Epoch 70/100
#  - 0s - loss: 0.2442 - acc: 0.9157 - val_loss: 0.0840 - val_acc: 0.9970
# Epoch 71/100
#  - 0s - loss: 0.2633 - acc: 0.9056 - val_loss: 0.0839 - val_acc: 0.9970
# Epoch 72/100
#  - 0s - loss: 0.3091 - acc: 0.8815 - val_loss: 0.0847 - val_acc: 0.9970
# Epoch 73/100
#  - 0s - loss: 0.2633 - acc: 0.9056 - val_loss: 0.0846 - val_acc: 0.9970
# Epoch 74/100
#  - 0s - loss: 0.2709 - acc: 0.9016 - val_loss: 0.0851 - val_acc: 0.9970
# Epoch 75/100
#  - 0s - loss: 0.3240 - acc: 0.8735 - val_loss: 0.0858 - val_acc: 0.9970
# Epoch 76/100
#  - 0s - loss: 0.2670 - acc: 0.9036 - val_loss: 0.0860 - val_acc: 0.9970
# Epoch 77/100
#  - 0s - loss: 0.2784 - acc: 0.8976 - val_loss: 0.0862 - val_acc: 0.9970
# Epoch 78/100
#  - 0s - loss: 0.2443 - acc: 0.9157 - val_loss: 0.0861 - val_acc: 0.9970
# Epoch 79/100
#  - 0s - loss: 0.2935 - acc: 0.8896 - val_loss: 0.0864 - val_acc: 0.9970
# Epoch 80/100
#  - 0s - loss: 0.2481 - acc: 0.9137 - val_loss: 0.0862 - val_acc: 0.9970
# Epoch 81/100
#  - 0s - loss: 0.2708 - acc: 0.9016 - val_loss: 0.0862 - val_acc: 0.9970
# Epoch 82/100
#  - 0s - loss: 0.2216 - acc: 0.9277 - val_loss: 0.0855 - val_acc: 0.9970
# Epoch 83/100
#  - 0s - loss: 0.3239 - acc: 0.8735 - val_loss: 0.0862 - val_acc: 0.9970
# Epoch 84/100
#  - 0s - loss: 0.2443 - acc: 0.9157 - val_loss: 0.0858 - val_acc: 0.9970
# Epoch 85/100
#  - 0s - loss: 0.2708 - acc: 0.9016 - val_loss: 0.0860 - val_acc: 0.9970
# Epoch 86/100
#  - 0s - loss: 0.2670 - acc: 0.9036 - val_loss: 0.0862 - val_acc: 0.9970
# Epoch 87/100
#  - 0s - loss: 0.2595 - acc: 0.9076 - val_loss: 0.0863 - val_acc: 0.9970
# Epoch 88/100
#  - 0s - loss: 0.2897 - acc: 0.8916 - val_loss: 0.0868 - val_acc: 0.9970
# Epoch 89/100
#  - 0s - loss: 0.2971 - acc: 0.8876 - val_loss: 0.0871 - val_acc: 0.9970
# Epoch 90/100
#  - 0s - loss: 0.2595 - acc: 0.9076 - val_loss: 0.0869 - val_acc: 0.9970
# Epoch 91/100
#  - 0s - loss: 0.2406 - acc: 0.9177 - val_loss: 0.0866 - val_acc: 0.9970
# Epoch 92/100
#  - 0s - loss: 0.2670 - acc: 0.9036 - val_loss: 0.0866 - val_acc: 0.9970
# Epoch 93/100
#  - 0s - loss: 0.2595 - acc: 0.9076 - val_loss: 0.0864 - val_acc: 0.9970
# Epoch 94/100
#  - 0s - loss: 0.2595 - acc: 0.9076 - val_loss: 0.0863 - val_acc: 0.9970
# Epoch 95/100
#  - 0s - loss: 0.2859 - acc: 0.8936 - val_loss: 0.0866 - val_acc: 0.9970
# Epoch 96/100
#  - 0s - loss: 0.2595 - acc: 0.9076 - val_loss: 0.0865 - val_acc: 0.9970
# Epoch 97/100
#  - 0s - loss: 0.2670 - acc: 0.9036 - val_loss: 0.0866 - val_acc: 0.9970
# Epoch 98/100
#  - 0s - loss: 0.2670 - acc: 0.9036 - val_loss: 0.0866 - val_acc: 0.9970
# Epoch 99/100
#  - 0s - loss: 0.2821 - acc: 0.8956 - val_loss: 0.0870 - val_acc: 0.9970
# Epoch 100/100
#  - 0s - loss: 0.2670 - acc: 0.9036 - val_loss: 0.0869 - val_acc: 0.9970

# %% [markdown]
# ## 6. Evaluating the model
# This will give you the accuracy of the model.

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("accuracy: ", score[1])
# Out:
# ('accuracy: ', 0.99698795180722888)
